# %%
# dependencies
import pandas as pd

# %%
# read in data
file_path = "resources/IBM_employee_data.csv"
attrition_df = pd.read_csv(file_path)
attrition_df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# list of columns from dataframe
attrition_df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
attrition_df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# PersonalFactors Table

# %%
# columns in table
personal_cols = ["Age", "DistanceFromHome", "Education", "EducationField", "EmployeeNumber", 
                 "EnvironmentSatisfaction", "Gender", "MaritalStatus", "NumCompaniesWorked","Over18",
                 "RelationshipSatisfaction", "TotalWorkingYears", "WorkLifeBalance"]

# %%
# subset original dataframe
personalFactor_df = attrition_df[personal_cols]
personalFactor_df.head()
# Out:
#    Age  DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0   41                 1          2  Life Sciences               1
# 1   49                 8          1  Life Sciences               2
# 2   37                 2          2          Other               4
# 3   33                 3          4  Life Sciences               5
# 4   27                 2          1        Medical               7
#
#    EnvironmentSatisfaction  Gender MaritalStatus  NumCompaniesWorked Over18  \
# 0                        2  Female        Single                   8      Y
# 1                        3    Male       Married                   1      Y
# 2                        4    Male        Single                   6      Y
# 3                        4  Female       Married                   1      Y
# 4                        1    Male       Married                   9      Y
#
#    RelationshipSatisfaction  TotalWorkingYears  WorkLifeBalance
# ...

# %%
# number of items in personal factors dataframe
len(personalFactor_df.columns)
# Out:
# 13

# %% [markdown]
# ProfessionalFactors table

# %%
professional_cols = ['Attrition', 'BusinessTravel', 'DailyRate', 'Department', 'EmployeeCount',
       'EmployeeNumber', 'HourlyRate',
       'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
       'MonthlyIncome', 'MonthlyRate',
       'OverTime', 'PercentSalaryHike', 'PerformanceRating',
       'StandardHours', 'StockOptionLevel', 'TrainingTimesLastYear',
       'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager']

# %%
# subset original dataframe
professionalFactors_df = attrition_df[professional_cols]
professionalFactors_df.head()
# Out:
#   Attrition     BusinessTravel  DailyRate              Department  \
# 0       Yes      Travel_Rarely       1102                   Sales
# 1        No  Travel_Frequently        279  Research & Development
# 2       Yes      Travel_Rarely       1373  Research & Development
# 3        No  Travel_Frequently       1392  Research & Development
# 4        No      Travel_Rarely        591  Research & Development
#
#    EmployeeCount  EmployeeNumber  HourlyRate  JobInvolvement  JobLevel  \
# 0              1               1          94               3         2
# 1              1               2          61               2         2
# 2              1               4          92               2         1
# 3              1               5          56               3         1
# 4              1               7          40               3         1
#
#                  JobRole  ...  OverTime  PercentSalaryHike  PerformanceRating  \
# ...

# %%
# number of items in professional factors dataframe
len(professionalFactors_df.columns)
# Out:
# 23

# %% [markdown]
# Move to csv

# %%
personalFactor_df.to_csv("resources/personalfactor.csv")

# %%
professionalFactors_df.to_csv("resources/professionalfactor.csv")
